# %%
git_url = "https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main"
part1_ch3 = git_url + "/part1/ch3/"
data_url = "https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/type1_data1.csv"

# %%
# transform
import pandas as pd
import numpy as np

df = pd.DataFrame({
    '브랜드': ['뉴발란스', '나이키', '아디다스', '나이키', '아디다스', '뉴발란스', '아디다스', '뉴발란스' ,'나이키'],
    '가격': [1000, np.nan, 1500, np.nan, 1200, np.nan, 1800, 800, 1300]
})
df
# Out:
#     브랜드      가격
# 0  뉴발란스  1000.0
# 1   나이키     NaN
# 2  아디다스  1500.0
# 3   나이키     NaN
# 4  아디다스  1200.0
# 5  뉴발란스     NaN
# 6  아디다스  1800.0
# 7  뉴발란스   800.0
# 8   나이키  1300.0

# %%
price = df.groupby('브랜드')['가격'].transform("mean")
price
# Out:
# 0     900.0
# 1    1300.0
# 2    1500.0
# 3    1300.0
# 4    1500.0
# 5     900.0
# 6    1500.0
# 7     900.0
# 8    1300.0
# Name: 가격, dtype: float64

# %%
df['가격'] = df['가격'].fillna(price)
df
# Out:
#     브랜드      가격
# 0  뉴발란스  1000.0
# 1   나이키  1300.0
# 2  아디다스  1500.0
# 3   나이키  1300.0
# 4  아디다스  1200.0
# 5  뉴발란스   900.0
# 6  아디다스  1800.0
# 7  뉴발란스   800.0
# 8   나이키  1300.0

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    '브랜드': ['뉴발란스', '나이키', '아디다스', '나이키', '아디다스', '뉴발란스', '아디다스', '뉴발란스' ,'나이키', '나이키'],
    '성별': ['남성', '여성', '여성', '남성', '남성', '여성', '여성', '여성', '남성', '여성'],
    '가격': [1000, np.nan, 1500, np.nan, 1200, np.nan, 1800, 800, 1300, 900]
})
df
# Out:
#     브랜드  성별      가격
# 0  뉴발란스  남성  1000.0
# 1   나이키  여성     NaN
# 2  아디다스  여성  1500.0
# 3   나이키  남성     NaN
# 4  아디다스  남성  1200.0
# 5  뉴발란스  여성     NaN
# 6  아디다스  여성  1800.0
# 7  뉴발란스  여성   800.0
# 8   나이키  남성  1300.0
# 9   나이키  여성   900.0

# %%
price = df.groupby(['성별', '브랜드'])['가격'].transform('mean')
price
# Out:
# 0    1000.0
# 1     900.0
# 2    1650.0
# 3    1300.0
# 4    1200.0
# 5     800.0
# 6    1650.0
# 7     800.0
# 8    1300.0
# 9     900.0
# Name: 가격, dtype: float64

# %%
df['가격'] = df['가격'].fillna(price)
df
# Out:
#     브랜드  성별      가격
# 0  뉴발란스  남성  1000.0
# 1   나이키  여성   900.0
# 2  아디다스  여성  1500.0
# 3   나이키  남성  1300.0
# 4  아디다스  남성  1200.0
# 5  뉴발란스  여성   800.0
# 6  아디다스  여성  1800.0
# 7  뉴발란스  여성   800.0
# 8   나이키  남성  1300.0
# 9   나이키  여성   900.0

# %%
grouped = df.groupby(['브랜드', '성별'])['가격'].mean()
grouped
# Out:
# 브랜드   성별
# 나이키   남성    1300.0
#       여성     900.0
# 뉴발란스  남성    1000.0
#       여성     800.0
# 아디다스  남성    1200.0
#       여성    1650.0
# Name: 가격, dtype: float64

# %%
grouped.unstack()
# Out:
# 성별        남성      여성
# 브랜드
# 나이키   1300.0   900.0
# 뉴발란스  1000.0   800.0
# 아디다스  1200.0  1650.0

# %%
grouped.unstack(level=-1)
# Out:
# 성별        남성      여성
# 브랜드
# 나이키   1300.0   900.0
# 뉴발란스  1000.0   800.0
# 아디다스  1200.0  1650.0

# %%
grouped.unstack(level=0)
# Out:
# 브랜드     나이키    뉴발란스    아디다스
# 성별
# 남성   1300.0  1000.0  1200.0
# 여성    900.0   800.0  1650.0

# %%
grouped.unstack(level=1)
# Out:
# 성별        남성      여성
# 브랜드
# 나이키   1300.0   900.0
# 뉴발란스  1000.0   800.0
# 아디다스  1200.0  1650.0

# %%
grouped.unstack().unstack()
# Out:
# 성별  브랜드
# 남성  나이키     1300.0
#     뉴발란스    1000.0
#     아디다스    1200.0
# 여성  나이키      900.0
#     뉴발란스     800.0
#     아디다스    1650.0
# dtype: float64

# %%
# 시계열 데이터
import pandas as pd

df = pd.DataFrame({
    'type1': ['2025-05-20'],
    'type2': ['2025:05:20'],
    'type3': ['2025/05/20'],
    'type4': ['20/05/2025'],
    'type5': ['20-May-2025'],
    'type6': ['2025-05-20 15:43:30'],
    'type7': ['2025-05-20 15-43-30'],
    'type8': ['2025-05-20 03:43:30 PM'],
    'type9': ['20/05/2025 03:43:30 PM'],
    'type10': ['20 May 2025 15:43:30']
})

df
# Out:
#         type1       type2       type3       type4        type5  \
# 0  2025-05-20  2025:05:20  2025/05/20  20/05/2025  20-May-2025
#
#                  type6                type7                   type8  \
# 0  2025-05-20 15:43:30  2025-05-20 15-43-30  2025-05-20 03:43:30 PM
#
#                     type9                type10
# 0  20/05/2025 03:43:30 PM  20 May 2025 15:43:30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   type1   1 non-null      object
#  1   type2   1 non-null      object
#  2   type3   1 non-null      object
#  3   type4   1 non-null      object
#  4   type5   1 non-null      object
#  5   type6   1 non-null      object
#  6   type7   1 non-null      object
#  7   type8   1 non-null      object
#  8   type9   1 non-null      object
#  9   type10  1 non-null      object
# dtypes: object(10)
# memory usage: 212.0+ bytes

# %%
# pd.to_datetime datetime으로 자료형 변경
df['type1'] = pd.to_datetime(df['type1'])
df['type2'] = pd.to_datetime(df['type2'], format='%Y:%m:%d')
df['type3'] = pd.to_datetime(df['type3'])
df['type4'] = pd.to_datetime(df['type4'])
df['type5'] = pd.to_datetime(df['type5'])
df['type6'] = pd.to_datetime(df['type6'])
df['type7'] = pd.to_datetime(df['type7'], format='%Y-%m-%d %H-%M-%S')
df['type8'] = pd.to_datetime(df['type8'])
df['type9'] = pd.to_datetime(df['type9'])
df['type10'] = pd.to_datetime(df['type10'])
df
# Out:
# <ipython-input-16-44502972fa5f>:5: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['type4'] = pd.to_datetime(df['type4'])
#        type1      type2      type3      type4      type5               type6  \
# 0 2025-05-20 2025-05-20 2025-05-20 2025-05-20 2025-05-20 2025-05-20 15:43:30
#
#                 type7               type8               type9  \
# 0 2025-05-20 15:43:30 2025-05-20 15:43:30 2025-05-20 15:43:30
#
#                type10
# 0 2025-05-20 15:43:30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   type1   1 non-null      datetime64[ns]
#  1   type2   1 non-null      datetime64[ns]
#  2   type3   1 non-null      datetime64[ns]
#  3   type4   1 non-null      datetime64[ns]
#  4   type5   1 non-null      datetime64[ns]
#  5   type6   1 non-null      datetime64[ns]
#  6   type7   1 non-null      datetime64[ns]
#  7   type8   1 non-null      datetime64[ns]
#  8   type9   1 non-null      datetime64[ns]
#  9   type10  1 non-null      datetime64[ns]
# dtypes: datetime64[ns](10)
# memory usage: 212.0 bytes

# %%
new_df = df.T
new_df.columns = ['date'] # 컬럼 이름 지정
new_df
# Out:
#                       date
# type1  2025-05-20 00:00:00
# type2  2025-05-20 00:00:00
# type3  2025-05-20 00:00:00
# type4  2025-05-20 00:00:00
# type5  2025-05-20 00:00:00
# type6  2025-05-20 15:43:30
# type7  2025-05-20 15:43:30
# type8  2025-05-20 15:43:30
# type9  2025-05-20 15:43:30
# type10 2025-05-20 15:43:30

# %%
new_df['year'] = new_df['date'].dt.year
new_df['month'] = new_df['date'].dt.month
new_df['day'] = new_df['date'].dt.day
new_df['hour'] = new_df['date'].dt.hour
new_df['min'] = new_df['date'].dt.minute
new_df['sec'] = new_df['date'].dt.second
new_df['dayofweek'] = new_df['date'].dt.dayofweek
new_df
# Out:
#                       date  year  month  day  hour  min  sec  dayofweek
# type1  2025-05-20 00:00:00  2025      5   20     0    0    0          1
# type2  2025-05-20 00:00:00  2025      5   20     0    0    0          1
# type3  2025-05-20 00:00:00  2025      5   20     0    0    0          1
# type4  2025-05-20 00:00:00  2025      5   20     0    0    0          1
# type5  2025-05-20 00:00:00  2025      5   20     0    0    0          1
# type6  2025-05-20 15:43:30  2025      5   20    15   43   30          1
# type7  2025-05-20 15:43:30  2025      5   20    15   43   30          1
# type8  2025-05-20 15:43:30  2025      5   20    15   43   30          1
# type9  2025-05-20 15:43:30  2025      5   20    15   43   30          1
# type10 2025-05-20 15:43:30  2025      5   20    15   43   30          1

# %%
print(df['type1'].dt.to_period('Y')) # 연도
print(df['type1'].dt.to_period('Q')) # 분기
print(df['type1'].dt.to_period('M')) # 월
print(df['type1'].dt.to_period('W')) # 주
print(df['type1'].dt.to_period('D')) # 일
print(df['type1'].dt.to_period('h')) # 시간
print(df['type1'].dt.to_period('min')) # 분
print(df['type1'].dt.to_period('s')) # 초
# print(df['type1'].dt.to_period('B')) # 영업일(범위 생성 후)
# Out:
# 0    2025
# Name: type1, dtype: period[Y-DEC]
# 0    2025Q2
# Name: type1, dtype: period[Q-DEC]
# 0    2025-05
# Name: type1, dtype: period[M]
# 0    2025-05-19/2025-05-25
# Name: type1, dtype: period[W-SUN]
# 0    2025-05-20
# Name: type1, dtype: period[D]
# 0    2025-05-20 00:00
# Name: type1, dtype: period[h]
# 0    2025-05-20 00:00
# Name: type1, dtype: period[min]
# 0    2025-05-20 00:00:00
# Name: type1, dtype: period[s]

# %%
d_day = pd.Timedelta(days=50)
new_df['50day'] = new_df['date'] + d_day
new_df
# Out:
#                       date  year  month  day  hour  min  sec  dayofweek  \
# type1  2025-05-20 00:00:00  2025      5   20     0    0    0          1
# type2  2025-05-20 00:00:00  2025      5   20     0    0    0          1
# type3  2025-05-20 00:00:00  2025      5   20     0    0    0          1
# type4  2025-05-20 00:00:00  2025      5   20     0    0    0          1
# type5  2025-05-20 00:00:00  2025      5   20     0    0    0          1
# type6  2025-05-20 15:43:30  2025      5   20    15   43   30          1
# type7  2025-05-20 15:43:30  2025      5   20    15   43   30          1
# type8  2025-05-20 15:43:30  2025      5   20    15   43   30          1
# type9  2025-05-20 15:43:30  2025      5   20    15   43   30          1
# type10 2025-05-20 15:43:30  2025      5   20    15   43   30          1
#
#                      50day
# type1  2025-07-09 00:00:00
# type2  2025-07-09 00:00:00
# type3  2025-07-09 00:00:00
# type4  2025-07-09 00:00:00
# type5  2025-07-09 00:00:00
# type6  2025-07-09 15:43:30
# type7  2025-07-09 15:43:30
# type8  2025-07-09 15:43:30
# type9  2025-07-09 15:43:30
# type10 2025-07-09 15:43:30

# %%
some_day = pd.Timedelta(weeks=3, days=3, hours=3, minutes=3, seconds=3)
new_df['some_day'] = new_df['date'] + some_day
new_df
# Out:
#                       date  year  month  day  hour  min  sec  dayofweek  \
# type1  2025-05-20 00:00:00  2025      5   20     0    0    0          1
# type2  2025-05-20 00:00:00  2025      5   20     0    0    0          1
# type3  2025-05-20 00:00:00  2025      5   20     0    0    0          1
# type4  2025-05-20 00:00:00  2025      5   20     0    0    0          1
# type5  2025-05-20 00:00:00  2025      5   20     0    0    0          1
# type6  2025-05-20 15:43:30  2025      5   20    15   43   30          1
# type7  2025-05-20 15:43:30  2025      5   20    15   43   30          1
# type8  2025-05-20 15:43:30  2025      5   20    15   43   30          1
# type9  2025-05-20 15:43:30  2025      5   20    15   43   30          1
# type10 2025-05-20 15:43:30  2025      5   20    15   43   30          1
#
#                      50day            some_day
# type1  2025-07-09 00:00:00 2025-06-13 03:03:03
# type2  2025-07-09 00:00:00 2025-06-13 03:03:03
# type3  2025-07-09 00:00:00 2025-06-13 03:03:03
# type4  2025-07-09 00:00:00 2025-06-13 03:03:03
# type5  2025-07-09 00:00:00 2025-06-13 03:03:03
# type6  2025-07-09 15:43:30 2025-06-13 18:46:33
# type7  2025-07-09 15:43:30 2025-06-13 18:46:33
# type8  2025-07-09 15:43:30 2025-06-13 18:46:33
# type9  2025-07-09 15:43:30 2025-06-13 18:46:33
# type10 2025-07-09 15:43:30 2025-06-13 18:46:33

# %%
diff = new_df['50day'] - new_df['some_day']
diff
# Out:
# type1    25 days 20:56:57
# type2    25 days 20:56:57
# type3    25 days 20:56:57
# type4    25 days 20:56:57
# type5    25 days 20:56:57
# type6    25 days 20:56:57
# type7    25 days 20:56:57
# type8    25 days 20:56:57
# type9    25 days 20:56:57
# type10   25 days 20:56:57
# dtype: timedelta64[ns]

# %%
print(diff.dt.total_seconds())
print(diff.dt.total_seconds()/60) # 분
print(diff.dt.total_seconds()/60/60) # 시간
print(diff.dt.total_seconds()/60/60/24) # 일
# Out:
# type1     2235417.0
# type2     2235417.0
# type3     2235417.0
# type4     2235417.0
# type5     2235417.0
# type6     2235417.0
# type7     2235417.0
# type8     2235417.0
# type9     2235417.0
# type10    2235417.0
# dtype: float64
# type1     37256.95
# type2     37256.95
# type3     37256.95
# type4     37256.95
# type5     37256.95
# type6     37256.95
# type7     37256.95
# type8     37256.95
# type9     37256.95
# type10    37256.95
# dtype: float64
# type1     620.949167
# type2     620.949167
# type3     620.949167
# type4     620.949167
# type5     620.949167
# type6     620.949167
# type7     620.949167
# type8     620.949167
# type9     620.949167
# type10    620.949167
# dtype: float64
# type1     25.872882
# type2     25.872882
# type3     25.872882
# type4     25.872882
# type5     25.872882
# type6     25.872882
# type7     25.872882
# type8     25.872882
# type9     25.872882
# type10    25.872882
# dtype: float64

# %%
print(round(diff.dt.total_seconds()))
print(round(diff.dt.total_seconds()/60)) # 분
print(round(diff.dt.total_seconds()/60/60)) # 시간
print(round(diff.dt.total_seconds()/60/60/24)) # 일
# Out:
# type1     2235417.0
# type2     2235417.0
# type3     2235417.0
# type4     2235417.0
# type5     2235417.0
# type6     2235417.0
# type7     2235417.0
# type8     2235417.0
# type9     2235417.0
# type10    2235417.0
# dtype: float64
# type1     37257.0
# type2     37257.0
# type3     37257.0
# type4     37257.0
# type5     37257.0
# type6     37257.0
# type7     37257.0
# type8     37257.0
# type9     37257.0
# type10    37257.0
# dtype: float64
# type1     621.0
# type2     621.0
# type3     621.0
# type4     621.0
# type5     621.0
# type6     621.0
# type7     621.0
# type8     621.0
# type9     621.0
# type10    621.0
# dtype: float64
# type1     26.0
# type2     26.0
# type3     26.0
# type4     26.0
# type5     26.0
# type6     26.0
# type7     26.0
# type8     26.0
# type9     26.0
# type10    26.0
# dtype: float64

# %% [markdown]
# ## 데이터프레임 병합

# %%
# concat
import pandas as pd

# 음료 메뉴
drink = pd.DataFrame({
    'Menu': ['Americano', 'Latte', 'Milk', 'Tea', 'Juice'],
    'Price': [2500, 3000, 3000, 3500, 3500]
})

# 디저트 메뉴
desserts = pd.DataFrame({
    'Menu': ['Cheese Cake', 'Cookie', 'Bread'],
    'Price': [5000, 3500, 4000]
})

print(drink)
print(desserts)

print()
concat_menu = pd.concat([drink, desserts], ignore_index=True)
print(concat_menu)
# Out:
#         Menu  Price
# 0  Americano   2500
# 1      Latte   3000
# 2       Milk   3000
# 3        Tea   3500
# 4      Juice   3500
#           Menu  Price
# 0  Cheese Cake   5000
# 1       Cookie   3500
# 2        Bread   4000
#
#           Menu  Price
# 0    Americano   2500
# 1        Latte   3000
# 2         Milk   3000
# 3          Tea   3500
# 4        Juice   3500
# 5  Cheese Cake   5000
# 6       Cookie   3500
# 7        Bread   4000

# %%
concat_menu2 = pd.concat([drink, desserts], axis=1)
concat_menu2 = concat_menu2.fillna(0)
concat_menu2
# Out:
#         Menu  Price         Menu   Price
# 0  Americano   2500  Cheese Cake  5000.0
# 1      Latte   3000       Cookie  3500.0
# 2       Milk   3000        Bread  4000.0
# 3        Tea   3500            0     0.0
# 4      Juice   3500            0     0.0

# %%
# merge
# 음료 메뉴
drink = pd.DataFrame({
    'Menu': ['Americano', 'Latte', 'Milk', 'Tea', 'Juice'],
    'Price': [2500, 3000, 3000, 3500, 3500]
})

# ICE 여부
hot_or_ice = pd.DataFrame({
    'Menu': ['Americano', 'Latte', 'Milk', 'Tea', 'Juice'],
    'Hot/Ice': ['Hot/Ice', 'Hot/Ice', 'Hot', 'Hot', 'Ice']
})

merge_menu = pd.merge(drink, hot_or_ice, on='Menu')
merge_menu
# Out:
#         Menu  Price  Hot/Ice
# 0  Americano   2500  Hot/Ice
# 1      Latte   3000  Hot/Ice
# 2       Milk   3000      Hot
# 3        Tea   3500      Hot
# 4      Juice   3500      Ice

# %% [markdown]
# ## 피벗테이블

# %%
import pandas as pd

# 의류 매장 카테고리별 판매량
data = {
    '제품명': ['티셔츠', '블라우스', '치마', '코트',  '바지', '벨트', '구두'],
    '카테고리': ['상의', '상의', '하의', '아우터', '하의', '액세서리', '신발'],
    '판매량': [300, 150, 100, 50, 250, 80, 40]
}

df = pd.DataFrame(data)
print('판매량 데이터')
print(df)

# 피벗테이블: 카테고리별 평균 판매량
pt = df.pivot_table(index='카테고리', values='판매량', aggfunc='mean')
print()
print('카테고리별 평균 판매량 데이터')
print(pt)
# Out:
# 판매량 데이터
#     제품명  카테고리  판매량
# 0   티셔츠    상의  300
# 1  블라우스    상의  150
# 2    치마    하의  100
# 3    코트   아우터   50
# 4    바지    하의  250
# 5    벨트  액세서리   80
# 6    구두    신발   40
#
# 카테고리별 평균 판매량 데이터
#         판매량
# 카테고리
# 상의    225.0
# 신발     40.0
# 아우터    50.0
# 액세서리   80.0
# 하의    175.0

# %%
import pandas as pd

# 의류 매장 카테고리별 판매량
data = {
    '성별': ['남성', '여성', '여성', '남성',  '남성', '남성', '여성'],
    '카테고리': ['상의', '상의', '하의', '아우터', '하의', '액세서리', '신발'],
    '판매량': [300, 150, 100, 50, 250, 80, 40]
}

df = pd.DataFrame(data)
print('판매량 데이터')
print(df)

# 피벗테이블: 성별 & 카테고리별 판매량 합계
pt = df.pivot_table(index='카테고리', columns='성별', values='판매량', aggfunc='sum')
pt = pt.fillna(0)
print()
print('성별 및 카테고리별 합계 판매량 데이터')
print(pt)
# Out:
# 판매량 데이터
#    성별  카테고리  판매량
# 0  남성    상의  300
# 1  여성    상의  150
# 2  여성    하의  100
# 3  남성   아우터   50
# 4  남성    하의  250
# 5  남성  액세서리   80
# 6  여성    신발   40
#
# 성별 및 카테고리별 합계 판매량 데이터
# 성별       남성     여성
# 카테고리
# 상의    300.0  150.0
# 신발      0.0   40.0
# 아우터    50.0    0.0
# 액세서리   80.0    0.0
# 하의    250.0  100.0

# %%
import pandas as pd

df = pd.DataFrame({
    "구분": ['상의', '상의', '상의', '상의', '하의', '하의', '하의', '하의'],
    "성별": ['남성', '남성', '여성', '여성', '여성', '여성', '남성', '여성'],
    "사이즈": ['XL', 'L', 'M', 'S', 'S', 'M', 'XL', 'L'],
    "판매량": [2, 3, 1, 5, 2, 4, 6, 3],
    "재고": [10, 5, 12, 8, 7, 6, 4, 3]
})

df
# Out:
#    구분  성별 사이즈  판매량  재고
# 0  상의  남성  XL    2  10
# 1  상의  남성   L    3   5
# 2  상의  여성   M    1  12
# 3  상의  여성   S    5   8
# 4  하의  여성   S    2   7
# 5  하의  여성   M    4   6
# 6  하의  남성  XL    6   4
# 7  하의  여성   L    3   3

# %%
pt = df.pivot_table(index=['구분', '성별'], columns=['사이즈'], values='판매량', aggfunc='sum', fill_value=0)
pt
# Out:
# 사이즈    L  M  S  XL
# 구분 성별
# 상의 남성  3  0  0   2
#    여성  0  1  5   0
# 하의 남성  0  0  0   6
#    여성  3  4  2   0

# %%
pt = df.pivot_table(
    index=['구분', '성별'],
    columns=['사이즈'],
    values=['판매량', '재고'],
    aggfunc={'판매량': 'mean', '재고': 'sum'},
    fill_value=0)

pt
# Out:
#       재고             판매량
# 사이즈    L   M  S  XL    L    M    S   XL
# 구분 성별
# 상의 남성  5   0  0  10  3.0  0.0  0.0  2.0
#    여성  0  12  8   0  0.0  1.0  5.0  0.0
# 하의 남성  0   0  0   4  0.0  0.0  0.0  6.0
#    여성  3   6  7   0  3.0  4.0  2.0  0.0

# %%
pt = df.pivot_table(
    index=['구분', '성별'],
    columns=['사이즈'],
    values=['판매량', '재고'],
    aggfunc={'판매량': 'mean', '재고': ['sum', 'mean', 'min', 'max']},
    fill_value=0)

pt
# Out:
#        재고                                                                 판매량  \
#       max            mean                  min            sum            mean
# 사이즈     L   M  S  XL    L     M    S    XL   L   M  S  XL   L   M  S  XL    L
# 구분 성별
# 상의 남성   5   0  0  10  5.0   0.0  0.0  10.0   5   0  0  10   5   0  0  10  3.0
#    여성   0  12  8   0  0.0  12.0  8.0   0.0   0  12  8   0   0  12  8   0  0.0
# 하의 남성   0   0  0   4  0.0   0.0  0.0   4.0   0   0  0   4   0   0  0   4  0.0
#    여성   3   6  7   0  3.0   6.0  7.0   0.0   3   6  7   0   3   6  7   0  3.0
#
#
#
# 사이즈      M    S   XL
# 구분 성별
# 상의 남성  0.0  0.0  2.0
#    여성  1.0  5.0  0.0
# 하의 남성  0.0  0.0  6.0
#    여성  4.0  2.0  0.0

# %%
pt.reset_index()
# Out:
#      구분  성별  재고                                   ...                         \
#             max            mean                   ... min     sum
# 사이즈           L   M  S  XL    L     M    S    XL  ...   S  XL   L   M  S  XL
# 0    상의  남성   5   0  0  10  5.0   0.0  0.0  10.0  ...   0  10   5   0  0  10
# 1    상의  여성   0  12  8   0  0.0  12.0  8.0   0.0  ...   8   0   0  12  8   0
# 2    하의  남성   0   0  0   4  0.0   0.0  0.0   4.0  ...   0   4   0   0  0   4
# 3    하의  여성   3   6  7   0  3.0   6.0  7.0   0.0  ...   7   0   3   6  7   0
#
#      판매량
#     mean
# 사이즈    L    M    S   XL
# 0    3.0  0.0  0.0  2.0
# 1    0.0  1.0  5.0  0.0
# 2    0.0  0.0  0.0  6.0
# 3    3.0  4.0  2.0  0.0
#
# [4 rows x 22 columns]
